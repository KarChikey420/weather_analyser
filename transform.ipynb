# %%
import pandas as pd

# %%
df=pd.read_csv("weather_data.csv")
df.head()
# Out:
#     city country             datetime  temperature  humidity weather  \
# 0  Delhi      IN  2025-10-17 18:00:00       297.20        69   Clear
# 1  Delhi      IN  2025-10-17 21:00:00       298.22        59   Clear
# 2  Delhi      IN  2025-10-18 00:00:00       298.61        53   Clear
# 3  Delhi      IN  2025-10-18 03:00:00       300.51        47   Clear
# 4  Delhi      IN  2025-10-18 06:00:00       304.80        33   Clear
#
#   description  wind_speed
# 0   clear sky        0.84
# 1   clear sky        1.29
# 2   clear sky        1.02
# 3   clear sky        1.28
# 4   clear sky        1.16

# %%
df['datetime'] = pd.to_datetime(df['datetime'])
df['date'] = df['datetime'].dt.date
df['time'] = df['datetime'].dt.time
df['hour'] = df['datetime'].dt.hour
df['minute'] = df['datetime'].dt.minute
df['weekday'] = df['datetime'].dt.day_name()
df['month'] = df['datetime'].dt.month_name()

# %%
df['temperature_celsius'] = df['temperature'] - 273.15
df['temperature_celsius'] = df['temperature_celsius'].round(2)

# %%
df.head()
# Out:
#     city country            datetime  temperature  humidity weather  \
# 0  Delhi      IN 2025-10-17 18:00:00       297.20        69   Clear
# 1  Delhi      IN 2025-10-17 21:00:00       298.22        59   Clear
# 2  Delhi      IN 2025-10-18 00:00:00       298.61        53   Clear
# 3  Delhi      IN 2025-10-18 03:00:00       300.51        47   Clear
# 4  Delhi      IN 2025-10-18 06:00:00       304.80        33   Clear
#
#   description  wind_speed        date      time  hour  minute   weekday  \
# 0   clear sky        0.84  2025-10-17  18:00:00    18       0    Friday
# 1   clear sky        1.29  2025-10-17  21:00:00    21       0    Friday
# 2   clear sky        1.02  2025-10-18  00:00:00     0       0  Saturday
# 3   clear sky        1.28  2025-10-18  03:00:00     3       0  Saturday
# 4   clear sky        1.16  2025-10-18  06:00:00     6       0  Saturday
#
#      month  temperature_celsius
# 0  October                24.05
# 1  October                25.07
# 2  October                25.46
# 3  October                27.36
# 4  October                31.65

# %%
df['is_hot_day'] = df['temperature_celsius'] > 30
df['is_rainy'] = df['weather'].str.contains("Rain", case=False)
df['is_night'] = df['hour'].apply(lambda x: x < 6 or x >= 18)

# %%
df.head()
# Out:
#     city country            datetime  temperature  humidity weather  \
# 0  Delhi      IN 2025-10-17 18:00:00       297.20        69   Clear
# 1  Delhi      IN 2025-10-17 21:00:00       298.22        59   Clear
# 2  Delhi      IN 2025-10-18 00:00:00       298.61        53   Clear
# 3  Delhi      IN 2025-10-18 03:00:00       300.51        47   Clear
# 4  Delhi      IN 2025-10-18 06:00:00       304.80        33   Clear
#
#   description  wind_speed        date      time  hour  minute   weekday  \
# 0   clear sky        0.84  2025-10-17  18:00:00    18       0    Friday
# 1   clear sky        1.29  2025-10-17  21:00:00    21       0    Friday
# 2   clear sky        1.02  2025-10-18  00:00:00     0       0  Saturday
# 3   clear sky        1.28  2025-10-18  03:00:00     3       0  Saturday
# 4   clear sky        1.16  2025-10-18  06:00:00     6       0  Saturday
#
#      month  temperature_celsius  is_hot_day  is_rainy  is_night
# 0  October                24.05       False     False      True
# 1  October                25.07       False     False      True
# 2  October                25.46       False     False      True
# 3  October                27.36       False     False      True
# 4  October                31.65        True     False     False

# %%
df1=df[['city','country','humidity','weather','wind_speed','date','time','hour','weekday','month','temperature_celsius','is_hot_day','is_rainy','is_night']]

# %%
df1.head()
# Out:
#     city country  humidity weather  wind_speed        date      time  hour  \
# 0  Delhi      IN        69   Clear        0.84  2025-10-17  18:00:00    18
# 1  Delhi      IN        59   Clear        1.29  2025-10-17  21:00:00    21
# 2  Delhi      IN        53   Clear        1.02  2025-10-18  00:00:00     0
# 3  Delhi      IN        47   Clear        1.28  2025-10-18  03:00:00     3
# 4  Delhi      IN        33   Clear        1.16  2025-10-18  06:00:00     6
#
#     weekday    month  temperature_celsius  is_hot_day  is_rainy  is_night
# 0    Friday  October                24.05       False     False      True
# 1    Friday  October                25.07       False     False      True
# 2  Saturday  October                25.46       False     False      True
# 3  Saturday  October                27.36       False     False      True
# 4  Saturday  October                31.65        True     False     False

# %%
df1 = df1.rename(columns={
    'city': 'City_Name',
    'country': 'Country_Name',
    'humidity': 'Humidity_Percent',
    'weather': 'Weather_Type',
    'wind_speed': 'WindSpeed',
    'temperature_celsius': 'Temperature',
    'is_hot_day': 'Hot_Day',
    'is_rainy': 'Rainy_Day',
    'is_night': 'Night_Time',
    'date': 'Date',
    'time': 'Time',
    'hour': 'Hour_of_Day',
    'weekday': 'Day_of_Week',
})

# %%
df1.head()
# Out:
#   City_Name Country_Name  Humidity_Percent Weather_Type  WindSpeed  \
# 0     Delhi           IN                69        Clear       0.84
# 1     Delhi           IN                59        Clear       1.29
# 2     Delhi           IN                53        Clear       1.02
# 3     Delhi           IN                47        Clear       1.28
# 4     Delhi           IN                33        Clear       1.16
#
#          Date      Time  Hour_of_Day Day_of_Week    month  Temperature  \
# 0  2025-10-17  18:00:00           18      Friday  October        24.05
# 1  2025-10-17  21:00:00           21      Friday  October        25.07
# 2  2025-10-18  00:00:00            0    Saturday  October        25.46
# 3  2025-10-18  03:00:00            3    Saturday  October        27.36
# 4  2025-10-18  06:00:00            6    Saturday  October        31.65
#
#    Hot_Day  Rainy_Day  Night_Time
# 0    False      False        True
# 1    False      False        True
# 2    False      False        True
# 3    False      False        True
# 4     True      False       False
